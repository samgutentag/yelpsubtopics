# %% [markdown]
# # Restaurant Data EDA

# %%
# %matplotlib inline
import numpy as np
import math
import matplotlib.pyplot as plt
import pandas as pd
import datetime
from glob import glob

import seaborn as sns
sns.set()
# sns.set_style('whitegrid')
# sns.set_context("poster")

# %%
def time_marker(text=''):
    print('[{}] {}'.format(datetime.datetime.now().time(), text))

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))

import matplotlib
font = {'size' : 50}
matplotlib.rc('font', **font)

TITLE_FONT_SIZE = 25
LABEL_FONT_SIZE = 15
TICK_FONT_SIZE  = 15

FIG_SIZE = (15,6)
FIG_SIZE_SQUARE = (15,15)
DO_WRITE_CHARTS = True
# Out:
# <style>.container { width:95% !important; }</style>

# %% [markdown]
# # Load Restaurant Data

# %%
time_marker(text='Loading Non Fast Food Data...')
restaurants = pd.read_csv('../clean_data/az_restaurant_business_clean.csv', index_col=0)
restaurants.reset_index(inplace=True, drop=True)
time_marker(text='Complete!')
# Out:
# [12:34:31.154817] Loading Non Fast Food Data...
# [12:34:31.216084] Complete!

# %%
restaurants['is_open'] = restaurants['is_open'].apply(lambda x: 'True' if x == 1 else 'False')
restaurants['is_fast_food'] = restaurants['is_fast_food'].apply(lambda x: 'True' if x == 1 else 'False')

# %%
restaurants.head()
# Out:
#                          address             business_id  \
# 0  777 E Thunderbird Rd, Ste 107  1WBkAuQg81kokZIPMpn9Zg
# 1           10720 E Southern Ave  kKx8iCJkomVQBdWHnmmOiA
# 2     8140 N Hayden Rd, Ste H115  VdlPZg2NAu8t8GkdbPLecg
# 3            2810 North 75th Ave  QkG3KUXwqZBW18A9k1xqCA
# 4               1455 W Elliot Rd  nigYwB_m1TQ1WosjSWi-Hw
#
#                                           categories        city is_open  \
# 0                         ['burgers', 'restaurants']     Phoenix    True
# 1                           ['restaurants', 'pizza']        Mesa    True
# 2  ['restaurants', 'gluten-free', 'indian', 'seaf...  Scottsdale    True
# 3  ['american_(traditional)', 'restaurants', 'sea...     Phoenix    True
# 4                         ['burgers', 'restaurants']     Gilbert   False
#
#                            name  postal_code  review_count  stars is_fast_food
# 0  Charr An American Burger Bar      85022.0           232    3.0        False
# 1          Little Caesars Pizza      85209.0             4    2.5        False
# 2  Tandoori Times Indian Bistro      85258.0           263    3.5        False
# 3                   Red Lobster      85035.0            37    2.5        False
# 4                Simply Burgers      85233.0             5    3.0        False

# %% [markdown]
# ## Split into `Fast Food` and `Non Fast Food` DataFrames

# %%
time_marker(text='Loading Non Fast Food Data...')
nff_restaurants = restaurants[restaurants.is_fast_food == 'False'].copy()
nff_restaurants.reset_index(inplace=True, drop=True)

time_marker(text='Loading Fast Food Data...')
ff_restaurants = restaurants[restaurants.is_fast_food == 'True'].copy()
ff_restaurants.reset_index(inplace=True, drop=True)

time_marker(text='Complete!')
# Out:
# [12:34:31.302678] Loading Non Fast Food Data...
# [12:34:31.312078] Loading Fast Food Data...
# [12:34:31.315222] Complete!

# %%
restaurants.head(3).transpose()
# Out:
#                                           0                         1  \
# address       777 E Thunderbird Rd, Ste 107      10720 E Southern Ave
# business_id          1WBkAuQg81kokZIPMpn9Zg    kKx8iCJkomVQBdWHnmmOiA
# categories       ['burgers', 'restaurants']  ['restaurants', 'pizza']
# city                                Phoenix                      Mesa
# is_open                                True                      True
# name           Charr An American Burger Bar      Little Caesars Pizza
# postal_code                           85022                     85209
# review_count                            232                         4
# stars                                     3                       2.5
# is_fast_food                          False                     False
#
#                                                               2
# address                              8140 N Hayden Rd, Ste H115
# business_id                              VdlPZg2NAu8t8GkdbPLecg
# categories    ['restaurants', 'gluten-free', 'indian', 'seaf...
# city                                                 Scottsdale
# is_open                                                    True
# name                               Tandoori Times Indian Bistro
# postal_code                                               85258
# review_count                                                263
# stars                                                       3.5
# is_fast_food                                              False

# %% [markdown]
# # Exploratory Data Analysis

# %%
def plot_ratings(df, title, cp):
    ax = plt.figure(figsize=FIG_SIZE)
    ax = sns.countplot(x="stars", data=df, palette=cp.title())

    ax.set_xlabel('Star Rating', size=LABEL_FONT_SIZE)
    ax.set_ylabel('Number of Restaurants', size=LABEL_FONT_SIZE)

    title = title
    ax.set_title(title, size=TITLE_FONT_SIZE)

    if DO_WRITE_CHARTS:
        plt.savefig('../charts/{}_bar.png'.format(title.lower().replace(' ', '_')))
    else:
        plt.show()
    plt.close()

# %%
restaurants.head()
# Out:
#                          address             business_id  \
# 0  777 E Thunderbird Rd, Ste 107  1WBkAuQg81kokZIPMpn9Zg
# 1           10720 E Southern Ave  kKx8iCJkomVQBdWHnmmOiA
# 2     8140 N Hayden Rd, Ste H115  VdlPZg2NAu8t8GkdbPLecg
# 3            2810 North 75th Ave  QkG3KUXwqZBW18A9k1xqCA
# 4               1455 W Elliot Rd  nigYwB_m1TQ1WosjSWi-Hw
#
#                                           categories        city is_open  \
# 0                         ['burgers', 'restaurants']     Phoenix    True
# 1                           ['restaurants', 'pizza']        Mesa    True
# 2  ['restaurants', 'gluten-free', 'indian', 'seaf...  Scottsdale    True
# 3  ['american_(traditional)', 'restaurants', 'sea...     Phoenix    True
# 4                         ['burgers', 'restaurants']     Gilbert   False
#
#                            name  postal_code  review_count  stars is_fast_food
# 0  Charr An American Burger Bar      85022.0           232    3.0        False
# 1          Little Caesars Pizza      85209.0             4    2.5        False
# 2  Tandoori Times Indian Bistro      85258.0           263    3.5        False
# 3                   Red Lobster      85035.0            37    2.5        False
# 4                Simply Burgers      85233.0             5    3.0        False

# %%
title = 'Arizona Restaurant Star Distribution'
plot_ratings(restaurants, title, 'Reds')

# %%
ff_restaurants.head()
# Out:
#                 address             business_id  \
# 0  719 E Thunderbird Rd  rDMptJYWtnMhpQu_rRXHng
# 1   1635 E Camelback Rd  iPa__LOhse-hobC2Xmp-Kw
# 2   3441 W Northern Ave  2v-8QQfMLX2PCz-0S6gISQ
# 3      1483 N Dysart Rd  mfQlXkeNhW1vz_1iq63mNQ
# 4      17032 N 99th Ave  6CpAWkTcqqNtGAfOsPeFUw
#
#                                           categories      city is_open  \
# 0            ['fast_food', 'burgers', 'restaurants']   Phoenix    True
# 1            ['restaurants', 'burgers', 'fast_food']   Phoenix    True
# 2              ['pizza', 'restaurants', 'fast_food']   Phoenix    True
# 3            ['restaurants', 'fast_food', 'mexican']  Avondale    True
# 4  ['american_(traditional)', 'restaurants', 'san...  Sun City    True
#
#                 name  postal_code  review_count  stars is_fast_food
# 0         McDonald's      85022.0            10    1.0         True
# 1         McDonald's      85016.0            34    3.0         True
# 2  Papa John's Pizza      85051.0             7    2.5         True
# 3           Del Taco      85323.0            23    2.5         True
# 4             Arby's      85373.0             9    3.5         True

# %%
title = 'Arizona Fast Food Restaurant Star Distribution'
plot_ratings(ff_restaurants, title, 'Greens')

# %%
nff_restaurants.head()
# Out:
#                          address             business_id  \
# 0  777 E Thunderbird Rd, Ste 107  1WBkAuQg81kokZIPMpn9Zg
# 1           10720 E Southern Ave  kKx8iCJkomVQBdWHnmmOiA
# 2     8140 N Hayden Rd, Ste H115  VdlPZg2NAu8t8GkdbPLecg
# 3            2810 North 75th Ave  QkG3KUXwqZBW18A9k1xqCA
# 4               1455 W Elliot Rd  nigYwB_m1TQ1WosjSWi-Hw
#
#                                           categories        city is_open  \
# 0                         ['burgers', 'restaurants']     Phoenix    True
# 1                           ['restaurants', 'pizza']        Mesa    True
# 2  ['restaurants', 'gluten-free', 'indian', 'seaf...  Scottsdale    True
# 3  ['american_(traditional)', 'restaurants', 'sea...     Phoenix    True
# 4                         ['burgers', 'restaurants']     Gilbert   False
#
#                            name  postal_code  review_count  stars is_fast_food
# 0  Charr An American Burger Bar      85022.0           232    3.0        False
# 1          Little Caesars Pizza      85209.0             4    2.5        False
# 2  Tandoori Times Indian Bistro      85258.0           263    3.5        False
# 3                   Red Lobster      85035.0            37    2.5        False
# 4                Simply Burgers      85233.0             5    3.0        False

# %%
title = 'Arizona Non Fast Food Restaurant Star Distribution'
plot_ratings(nff_restaurants, title, 'Blues')

# %% [markdown]
# # Inspect Restaurants by Category

# %%
# get all unique categories

all_category_list = []
for sublist in [cat for cat in list(restaurants['categories'].values)]:
    sublist_parts = sublist.split("', '")
    
    for part in sublist_parts:
        part = part.strip("[]").strip("'")
        if len(part) > 1:
            all_category_list.append(part)
            
all_category_list = sorted(list(set(all_category_list)))

# %%
def plot_category_closures(df, category, category_label):
    
    data = df[df.categories.apply(lambda x: category in x)].copy()
    data.sort_values(['is_open', 'is_fast_food'], inplace=True, ascending=False)
    
    # prune tailing 's' from category label
    if category_label.endswith('s'):
        category_label = category_label[:-1]
    
    if category_label == 'fast_food':
        category_label = 'All Fast Food'
    if category_label == 'restaurant':
        category_label = 'All '
    
    if data.shape[0] > 100:
        
        category_label = category_label.replace('(', '').replace(')', '').replace('_', ' ')

        g = sns.factorplot(x="stars", y="review_count", hue="is_open", col="is_fast_food", data=data, kind="swarm", size=6, aspect=1, palette=['#78C850', '#C03028'])

        g.fig.suptitle('{} Resturants'.format(category_label.title()), size=TITLE_FONT_SIZE)

        if DO_WRITE_CHARTS:
            plt.savefig('../charts/categorical/{}_swarmplot.png'.format(category_label.lower().replace(' ', '_')))
        else:
            plt.show()
        plt.close()

# %%
for cat in all_category_list:
    time_marker('Plotting {} Locations...'.format(cat))
    plot_category_closures(restaurants, cat, cat)
# Out:
# [12:34:32.447766] Plotting afghan Locations...
# [12:34:32.458577] Plotting african Locations...
# [12:34:32.467312] Plotting american_(new) Locations...
# [12:34:33.298703] Plotting american_(traditional) Locations...
# [12:34:34.473902] Plotting arabian Locations...
# [12:34:34.479497] Plotting argentine Locations...
# [12:34:34.484521] Plotting armenian Locations...
# [12:34:34.489463] Plotting asian_fusion Locations...
# [12:34:35.063395] Plotting austrian Locations...
# [12:34:35.069374] Plotting barbeque Locations...
# [12:34:35.496441] Plotting belgian Locations...
# [12:34:35.502311] Plotting brazilian Locations...
# [12:34:35.507877] Plotting breakfast_&_brunch Locations...
# [12:34:36.329427] Plotting british Locations...
# [12:34:36.336830] Plotting buffets Locations...
# [12:34:36.838281] Plotting burgers Locations...
# [12:34:37.983934] Plotting burmese Locations...
# [12:34:37.992604] Plotting cajun/creole Locations...
# [12:34:37.998685] Plotting cambodian Locations...
# [12:34:38.003473] Plotting cantonese Locations...
# [12:34:38.008616] Plotting caribbean Locations...
# [12:34:38.014322] Plotting cheesesteaks Locations...
# [12:34:38.020427] Plotting chicken_wings Locations...
# [12:34:38.677844] Plotting chinese Locations...
# [12:34:39.594466] Plotting colombian Locations...
# [12:34:39.601978] Plotting comfort_food Locations...
# [12:34:39.608419] Plotting creperies Locations...
# [12:34:39.613249] Plotting cuban Locations...
# [12:34:39.618147] Plotting delis Locations...
# [12:34:40.220853] Plotting dim_sum Locations...
# [12:34:40.227484] Plotting diners Locations...
# [12:34:40.726789] Plotting dominican Locations...
# [12:34:40.732465] Plotting ethiopian Locations...
# [12:34:40.737131] Plotting falafel Locations...
# [12:34:40.742011] Plotting fast_food Locations...
# [12:34:47.171411] Plotting filipino Locations...
# [12:34:47.177815] Plotting fish_&_chips Locations...
# [12:34:47.183285] Plotting fondue Locations...
# [12:34:47.189410] Plotting food_court Locations...
# [12:34:47.194134] Plotting food_stands Locations...
# [12:34:47.199079] Plotting french Locations...
# [12:34:47.204027] Plotting gastropubs Locations...
# [12:34:47.208767] Plotting german Locations...
# [12:34:47.213498] Plotting gluten-free Locations...
# [12:34:47.218697] Plotting greek Locations...
# [12:34:47.866878] Plotting halal Locations...
# [12:34:47.874562] Plotting hawaiian Locations...
# [12:34:47.882213] Plotting hot_dogs Locations...
# [12:34:48.431506] Plotting hot_pot Locations...
