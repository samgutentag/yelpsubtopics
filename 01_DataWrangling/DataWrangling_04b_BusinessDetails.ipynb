# %% [markdown]
# # Yelp Business Wrangling

# %%
import numpy as np
import pandas as pd
import datetime
import json

DRY_RUN = False

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
# Out:
# <style>.container { width:95% !important; }</style>

# %%
day_labels = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

def time_marker(text=''):
    print('[{}] {}'.format(datetime.datetime.now().time(), text.title()))

def unpack(df, column, fillna=None):
    ret = None
    if fillna is None:
        ret = pd.concat([df, pd.DataFrame((d for idx, d in df[column].iteritems()))], axis=1)
        del ret[column]
    else:
        ret = pd.concat([df, pd.DataFrame((d for idx, d in df[column].iteritems())).fillna(fillna)], axis=1)
        del ret[column]
    return ret

# %% [markdown]
# # Load Business Data

# %%
time_marker(text='Loading Business Info Data...')

data = pd.DataFrame()
source_data_file = '../source_data/business.json'

biz_list = []
for line in open(source_data_file, 'r'):
    biz_list.append(json.loads(line))

time_marker(text='creating dataframe...')
biz_df = pd.DataFrame(biz_list)

time_marker(text='set index to business_id...')
biz_df.set_index('business_id', inplace=True, drop=True)
    
biz_df.head(3)
# Out:
# [16:37:03.293527] Loading Business Info Data...
# [16:37:10.724892] Creating Dataframe...
# [16:37:11.807155] Set Index To Business_Id...
#                                     address  \
# business_id
# YDf95gJZaq05wvo7hTQbbQ      691 Richmond Rd
# mLwM-h2YhXl2NCgdS84_Bw       2824 Milton Rd
# v2WhjAB3PIBA8J8VxG3wEg  337 Danforth Avenue
#
#                                                                attributes  \
# business_id
# YDf95gJZaq05wvo7hTQbbQ  {'RestaurantsPriceRange2': 2, 'BusinessParking...
# mLwM-h2YhXl2NCgdS84_Bw  {'GoodForMeal': {'dessert': False, 'latenight'...
# v2WhjAB3PIBA8J8VxG3wEg  {'BusinessParking': {'garage': False, 'street'...
#
#                                                                categories  \
# business_id
# YDf95gJZaq05wvo7hTQbbQ                       [Shopping, Shopping Centers]
# mLwM-h2YhXl2NCgdS84_Bw  [Food, Soul Food, Convenience Stores, Restaura...
# v2WhjAB3PIBA8J8VxG3wEg                               [Food, Coffee & Tea]
#
#                                     city  \
# business_id
# YDf95gJZaq05wvo7hTQbbQ  Richmond Heights
# mLwM-h2YhXl2NCgdS84_Bw         Charlotte
# v2WhjAB3PIBA8J8VxG3wEg           Toronto
#
#                                                                     hours  \
# business_id
# YDf95gJZaq05wvo7hTQbbQ  {'Monday': '10:00-21:00', 'Tuesday': '10:00-21...
# mLwM-h2YhXl2NCgdS84_Bw  {'Monday': '10:00-22:00', 'Tuesday': '10:00-22...
# v2WhjAB3PIBA8J8VxG3wEg  {'Monday': '10:00-19:00', 'Tuesday': '10:00-19...
#
#                         is_open   latitude  longitude  \
# business_id
# YDf95gJZaq05wvo7hTQbbQ        1  41.541716 -81.493116
# mLwM-h2YhXl2NCgdS84_Bw        0  35.236870 -80.741976
# v2WhjAB3PIBA8J8VxG3wEg        0  43.677126 -79.353285
#
#                                                       name neighborhood  \
# business_id
# YDf95gJZaq05wvo7hTQbbQ                Richmond Town Square
# mLwM-h2YhXl2NCgdS84_Bw  South Florida Style Chicken & Ribs     Eastland
# v2WhjAB3PIBA8J8VxG3wEg                    The Tea Emporium    Riverdale
#
#                        postal_code  review_count  stars state
# business_id
# YDf95gJZaq05wvo7hTQbbQ       44143            17    2.0    OH
# mLwM-h2YhXl2NCgdS84_Bw       28215             4    4.5    NC
# v2WhjAB3PIBA8J8VxG3wEg     M4K 1N7             7    4.5    ON

# %% [markdown]
# # Separate `hours` column into daily open and close columns

# %%
time_marker(text='collecting business Hours...')
biz_hours = biz_df[['hours']].copy()

time_marker('splitting hours into individual columns...')
biz_hours = pd.concat([biz_hours.drop(['hours'], axis=1), biz_hours['hours'].apply(pd.Series)], axis=1)

time_marker(text='Split hours into open and close...')
# split daily hours columns into '{DAY}_open' and '{DAY}_close'
for col in biz_hours.columns:

    # split hours column of [11:00-19:00] into '{original_name}_open' and '{original_name}_close' columns
    biz_hours['{}_open'.format(col.lower())]  = pd.to_datetime(biz_hours[col].str.split('-', 1).str[0], format='%H:%M').dt.time
    biz_hours['{}_close'.format(col.lower())] = pd.to_datetime(biz_hours[col].str.split('-', 1).str[1], format='%H:%M').dt.time
    
    # drop original day columns
    biz_hours.drop(col, axis=1, inplace=True)

time_marker('sorting day columns order...')
cols = [['{}_open'.format(x.lower()), '{}_close'.format(x.lower())] for x in day_labels]
ordered_cols = list()
for day in cols:
    for time in day:
        ordered_cols.append(time)
        
biz_hours = biz_hours[ordered_cols].copy()

# merge back to original data frame
time_marker(text='merge open and close hours to business data...')
biz_df = biz_df.merge(biz_hours, left_index=True, right_index=True)

biz_df.drop(['hours'], axis=1, inplace=True)

biz_df.head(10)
# Out:
# [16:37:14.768932] Collecting Business Hours...
# [16:37:14.786055] Splitting Hours Into Individual Columns...
# [16:38:29.307331] Split Hours Into Open And Close...
# [21:40:09.775531] Sorting Day Columns Order...
# [21:40:10.034447] Merge Open And Close Hours To Business Data...
#                                                     address  \
# business_id
# YDf95gJZaq05wvo7hTQbbQ                      691 Richmond Rd
# mLwM-h2YhXl2NCgdS84_Bw                       2824 Milton Rd
# v2WhjAB3PIBA8J8VxG3wEg                  337 Danforth Avenue
# CVtCbSB1zUcUWg-9TNGTuQ  7702 E Doubletree Ranch Rd, Ste 300
# duHFBe87uNSXImQmvBh87Q                       4719 N 20Th St
# uUEMrhJiL1a1pCA_I1SU7Q                  2017 E Camelback Rd
# 2eJEUJIP54tex7T9YOcLSw              4425 N 24th St, Ste 125
# fEylCY3UEH8YJ0Xa7lu6lA                       5770 Butler St
# kFtuYklkAIlmYw8RZAieGw                   3220 Washington Rd
# NqiQdFa93wzUJGo29NbTPQ            1425 S Higley Rd, Ste 103
#
#                                                                attributes  \
# business_id
# YDf95gJZaq05wvo7hTQbbQ  {'RestaurantsPriceRange2': 2, 'BusinessParking...
# mLwM-h2YhXl2NCgdS84_Bw  {'GoodForMeal': {'dessert': False, 'latenight'...
# v2WhjAB3PIBA8J8VxG3wEg  {'BusinessParking': {'garage': False, 'street'...
# CVtCbSB1zUcUWg-9TNGTuQ                                                 {}
# duHFBe87uNSXImQmvBh87Q  {'RestaurantsTableService': False, 'GoodForMea...
# uUEMrhJiL1a1pCA_I1SU7Q  {'BusinessAcceptsCreditCards': True, 'Restaura...
# 2eJEUJIP54tex7T9YOcLSw  {'AcceptsInsurance': True, 'ByAppointmentOnly'...
# fEylCY3UEH8YJ0Xa7lu6lA               {'BusinessAcceptsCreditCards': True}
# kFtuYklkAIlmYw8RZAieGw  {'DogsAllowed': True, 'BusinessParking': {'gar...
# NqiQdFa93wzUJGo29NbTPQ  {'AcceptsInsurance': True, 'ByAppointmentOnly'...
#
#                                                                categories  \
# business_id
# YDf95gJZaq05wvo7hTQbbQ                       [Shopping, Shopping Centers]
# mLwM-h2YhXl2NCgdS84_Bw  [Food, Soul Food, Convenience Stores, Restaura...
# v2WhjAB3PIBA8J8VxG3wEg                               [Food, Coffee & Tea]
# CVtCbSB1zUcUWg-9TNGTuQ               [Professional Services, Matchmakers]
# duHFBe87uNSXImQmvBh87Q                          [Sandwiches, Restaurants]
# uUEMrhJiL1a1pCA_I1SU7Q                          [Shopping, Tobacco Shops]
# 2eJEUJIP54tex7T9YOcLSw                  [Chiropractors, Health & Medical]
# fEylCY3UEH8YJ0Xa7lu6lA  [Automotive, Oil Change Stations, Car Wash, Au...
# kFtuYklkAIlmYw8RZAieGw  [Jewelry Repair, Gold Buyers, Local Services, ...
# NqiQdFa93wzUJGo29NbTPQ                   [Health & Medical, Optometrists]
#
#                                     city  is_open   latitude   longitude  \
# business_id
# YDf95gJZaq05wvo7hTQbbQ  Richmond Heights        1  41.541716  -81.493116
# mLwM-h2YhXl2NCgdS84_Bw         Charlotte        0  35.236870  -80.741976
# v2WhjAB3PIBA8J8VxG3wEg           Toronto        0  43.677126  -79.353285
# CVtCbSB1zUcUWg-9TNGTuQ        Scottsdale        1  33.565082 -111.916400
# duHFBe87uNSXImQmvBh87Q           Phoenix        0  33.505928 -112.038847
# uUEMrhJiL1a1pCA_I1SU7Q           Phoenix        0  33.508068 -112.037552
# 2eJEUJIP54tex7T9YOcLSw           Phoenix        1  33.502848 -112.012696
# fEylCY3UEH8YJ0Xa7lu6lA        Pittsburgh        1  40.485939  -79.943727
# kFtuYklkAIlmYw8RZAieGw          McMurray        1  40.290498  -80.110021
# NqiQdFa93wzUJGo29NbTPQ           Gilbert        1  33.324539 -111.720449
#
#                                                       name   neighborhood  \
# business_id
# YDf95gJZaq05wvo7hTQbbQ                Richmond Town Square
# mLwM-h2YhXl2NCgdS84_Bw  South Florida Style Chicken & Ribs       Eastland
# v2WhjAB3PIBA8J8VxG3wEg                    The Tea Emporium      Riverdale
# CVtCbSB1zUcUWg-9TNGTuQ                            TRUmatch
# duHFBe87uNSXImQmvBh87Q                             Blimpie
# uUEMrhJiL1a1pCA_I1SU7Q                     Baxter's Cigars
# 2eJEUJIP54tex7T9YOcLSw            Back-Health Chiropractic
# fEylCY3UEH8YJ0Xa7lu6lA                       Auto Bathouse  Lawrenceville
# kFtuYklkAIlmYw8RZAieGw                 JAB Jewelry Designs
# NqiQdFa93wzUJGo29NbTPQ          Neighborhood Vision Center
#
#                        postal_code     ...       wednesday_open  \
# business_id                            ...
# YDf95gJZaq05wvo7hTQbbQ       44143     ...             10:00:00
# mLwM-h2YhXl2NCgdS84_Bw       28215     ...             10:00:00
# v2WhjAB3PIBA8J8VxG3wEg     M4K 1N7     ...             10:00:00
# CVtCbSB1zUcUWg-9TNGTuQ       85258     ...             09:00:00
# duHFBe87uNSXImQmvBh87Q       85016     ...                  NaN
# uUEMrhJiL1a1pCA_I1SU7Q       85016     ...             10:00:00
# 2eJEUJIP54tex7T9YOcLSw       85016     ...             14:30:00
# fEylCY3UEH8YJ0Xa7lu6lA       15201     ...             08:00:00
# kFtuYklkAIlmYw8RZAieGw       15317     ...             10:00:00
# NqiQdFa93wzUJGo29NbTPQ       85296     ...             07:30:00
#
#                         wednesday_close thursday_open thursday_close  \
# business_id
# YDf95gJZaq05wvo7hTQbbQ         21:00:00      10:00:00       21:00:00
# mLwM-h2YhXl2NCgdS84_Bw         22:00:00      10:00:00       22:00:00
# v2WhjAB3PIBA8J8VxG3wEg         19:00:00      10:00:00       19:00:00
# CVtCbSB1zUcUWg-9TNGTuQ         17:00:00      09:00:00       17:00:00
# duHFBe87uNSXImQmvBh87Q              NaN           NaN            NaN
# uUEMrhJiL1a1pCA_I1SU7Q         20:00:00      10:00:00       20:00:00
# 2eJEUJIP54tex7T9YOcLSw         17:00:00      14:00:00       19:00:00
# fEylCY3UEH8YJ0Xa7lu6lA         17:00:00      08:00:00       17:00:00
# kFtuYklkAIlmYw8RZAieGw         20:00:00      10:00:00       20:00:00
# NqiQdFa93wzUJGo29NbTPQ         17:00:00      07:30:00       17:00:00
#
#                        friday_open friday_close saturday_open saturday_close  \
# business_id
# YDf95gJZaq05wvo7hTQbbQ    10:00:00     21:00:00      10:00:00       21:00:00
# mLwM-h2YhXl2NCgdS84_Bw    10:00:00     22:00:00      10:00:00       22:00:00
# v2WhjAB3PIBA8J8VxG3wEg    10:00:00     19:00:00      10:00:00       18:00:00
# CVtCbSB1zUcUWg-9TNGTuQ    09:00:00     17:00:00           NaN            NaN
# duHFBe87uNSXImQmvBh87Q         NaN          NaN           NaN            NaN
# uUEMrhJiL1a1pCA_I1SU7Q    10:00:00     21:00:00      10:00:00       21:00:00
# 2eJEUJIP54tex7T9YOcLSw    09:00:00     12:00:00           NaN            NaN
# fEylCY3UEH8YJ0Xa7lu6lA    08:00:00     17:00:00      08:00:00       17:00:00
# kFtuYklkAIlmYw8RZAieGw    10:00:00     18:00:00      10:00:00       16:00:00
# NqiQdFa93wzUJGo29NbTPQ    07:30:00     11:00:00           NaN            NaN
#
#                        sunday_open sunday_close
# business_id
# YDf95gJZaq05wvo7hTQbbQ    11:00:00     18:00:00
# mLwM-h2YhXl2NCgdS84_Bw    10:00:00     22:00:00
# v2WhjAB3PIBA8J8VxG3wEg    12:00:00     17:00:00
# CVtCbSB1zUcUWg-9TNGTuQ         NaN          NaN
# duHFBe87uNSXImQmvBh87Q         NaN          NaN
# uUEMrhJiL1a1pCA_I1SU7Q    10:00:00     19:00:00
# 2eJEUJIP54tex7T9YOcLSw         NaN          NaN
# fEylCY3UEH8YJ0Xa7lu6lA    08:00:00     16:30:00
# kFtuYklkAIlmYw8RZAieGw         NaN          NaN
# NqiQdFa93wzUJGo29NbTPQ         NaN          NaN
#
# [10 rows x 27 columns]

# %% [markdown]
# # Separate `attributes` column into columns

# %%
attributes_df = biz_df[:2000]['attributes'].apply(pd.Series)
attributes_df.columns = [str(x).lower() for x in attributes_df.columns]

# %%
expandable_cols = ['businessparking','goodformeal','ambience','hairspecializesin','music','bestnights','dietaryrestrictions']

for excol in [col for col in attributes_df.columns if col != 0]:
    df = attributes_df[excol].apply(pd.Series)
    df.columns = ['{}_{}'.format(excol, str(x).lower()) for x in df.columns]
    
    # append to attributes_df
    attributes_df = attributes_df.merge(df, left_index=True, right_index=True)
    
    # drop original column
    attributes_df.drop([excol], axis=1, inplace=True)

# if attribute column ends in '_0', trim it
col_names = list()
for col in attributes_df.columns:
    if col.endswith('_0'):
        col_names.append(col[:-2])
    else:
        col_names.append(col)
# correct collumn names
attributes_df.columns = col_names

# time_marker('encoding 0/1 to False/True...')
# for col in attributes_df.columns:
#     if len(attributes_df[col].unique()) < 4:
#         print(col)
#         attributes_df[col] = attributes_df[col].replace(0.0, False).replace(1.0, True)

time_marker('drop')
df=df.dropna(axis=1,how='all')

# %%
for col in attributes_df.columns:
    print('{}{}'.format(str(col).ljust(40), attributes_df[col].unique()))

# %% [markdown]
# ### Merge back to biz_df

# %%
biz_df = biz_df.merge(attributes_df, left_index=True, right_index=True)
biz_df.drop(['attributes'], axis=1, inplace=True)

biz_df.head(3)

# %%
for col in biz_df.columns[2:]:
    print('\n')
    print('-' * 80)
    try:
        print('{}{}'.format(str(col).ljust(40), sorted(biz_df[col].unique())))
    except:
        print('{}{}'.format(str(col).ljust(40), biz_df[col].unique()))

# %%
time_marker(text='cleaning up and reset index...')
unpacked_biz_df.reset_index(inplace=True, drop=True)

# %%
# make all columns lower case
unpacked_biz_df.columns = [str(x).lower() for x in unpacked_biz_df.columns]

# %% [markdown]
# # One Hot Encode `categories` with sklearn
# <p>Save to separate file</p>

# %%
from sklearn.preprocessing import MultiLabelBinarizer
mlb = MultiLabelBinarizer()

# %%
biz_cat = biz_df[['business_id', 'categories']].copy()
biz_cat.set_index('business_id', inplace=True)
biz_cat.head(3)

# %%
time_marker('one hot encoding of categories started...')
biz_cat = biz_cat.join(pd.DataFrame(mlb.fit_transform(biz_cat.pop('categories')),
                          columns=mlb.classes_,
                          index=biz_cat.index))
time_marker('complete!')

# %%
restaurants = biz_cat[(biz_cat.Restaurants == 1) | (biz_cat.Food == 1)].copy()
restaurants = restaurants.replace(0, np.nan)
restaurants = restaurants.dropna(how='all', axis=1)
restaurants.shape

# %%
biz_df.shape

# %% [markdown]
# # Write to Files

# %%
time_marker(text='Writing to files...')

for rating in biz_df.stars.unique()):
    df = biz_df[biz_df.stars == rating].copy()
    df.reset_index(inplace=True, drop=True)

    file_name = '../clean_data/business/{}_star_business_clean.csv'.format(rating)
    time_marker(text='Writing {} rated records file...'.format(rating))
    if DRY_RUN:
        pass
    else:
        df.to_csv(file_name, encoding='utf-8')
