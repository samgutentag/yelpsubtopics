# %% [markdown]
# # Yelp Business Wrangling

# %%
# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import datetime

import json

import seaborn as sns
sns.set()
# sns.set_style('whitegrid')
# sns.set_context("poster")

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
# Out:
# <style>.container { width:95% !important; }</style>

# %% [markdown]
# # Load Business Data

# %%
print('[%s] Loading Business Data...' % datetime.datetime.now().time())

data = pd.DataFrame()
source_data_file = '../source_data/business.json'

biz_list = []
for line in open(source_data_file, 'r'):
    biz_list.append(json.loads(line))

print('[%s] creating dataframe...' % datetime.datetime.now().time())    
biz_df = pd.DataFrame(biz_list)

print('[%s] data type cleanup...' % datetime.datetime.now().time())    
# tips_df.date        = pd.to_datetime(tips_df.date)
# tips_df.likes       = tips_df.likes.astype('int')
    
print('[%s] Complete!' % datetime.datetime.now().time())
# Out:
# [16:07:01.452429] Loading Business Data...
# [16:07:21.019387] creating dataframe...
# [16:07:24.057651] data type cleanup...
# [16:07:24.057939] Complete!

# %%
biz_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156639 entries, 0 to 156638
# Data columns (total 15 columns):
# address         156639 non-null object
# attributes      156639 non-null object
# business_id     156639 non-null object
# categories      156639 non-null object
# city            156639 non-null object
# hours           156639 non-null object
# is_open         156639 non-null int64
# latitude        156638 non-null float64
# longitude       156638 non-null float64
# name            156639 non-null object
# neighborhood    156639 non-null object
# postal_code     156639 non-null object
# review_count    156639 non-null int64
# stars           156639 non-null float64
# state           156639 non-null object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 17.9+ MB

# %%
biz_df.head()
# Out:
#                                address  \
# 0                      691 Richmond Rd
# 1                       2824 Milton Rd
# 2                  337 Danforth Avenue
# 3  7702 E Doubletree Ranch Rd, Ste 300
# 4                       4719 N 20Th St
#
#                                           attributes             business_id  \
# 0  {'RestaurantsPriceRange2': 2, 'BusinessParking...  YDf95gJZaq05wvo7hTQbbQ
# 1  {'GoodForMeal': {'dessert': False, 'latenight'...  mLwM-h2YhXl2NCgdS84_Bw
# 2  {'BusinessParking': {'garage': False, 'street'...  v2WhjAB3PIBA8J8VxG3wEg
# 3                                                 {}  CVtCbSB1zUcUWg-9TNGTuQ
# 4  {'RestaurantsTableService': False, 'GoodForMea...  duHFBe87uNSXImQmvBh87Q
#
#                                           categories              city  \
# 0                       [Shopping, Shopping Centers]  Richmond Heights
# 1  [Food, Soul Food, Convenience Stores, Restaura...         Charlotte
# 2                               [Food, Coffee & Tea]           Toronto
# 3               [Professional Services, Matchmakers]        Scottsdale
# 4                          [Sandwiches, Restaurants]           Phoenix
#
#                                                hours  is_open   latitude  \
# 0  {'Monday': '10:00-21:00', 'Tuesday': '10:00-21...        1  41.541716
# 1  {'Monday': '10:00-22:00', 'Tuesday': '10:00-22...        0  35.236870
# 2  {'Monday': '10:00-19:00', 'Tuesday': '10:00-19...        0  43.677126
# 3  {'Friday': '9:00-17:00', 'Tuesday': '9:00-17:0...        1  33.565082
# 4                                                 {}        0  33.505928
#
#     longitude                                name neighborhood postal_code  \
# 0  -81.493116                Richmond Town Square                    44143
# 1  -80.741976  South Florida Style Chicken & Ribs     Eastland       28215
# 2  -79.353285                    The Tea Emporium    Riverdale     M4K 1N7
# 3 -111.916400                            TRUmatch                    85258
# 4 -112.038847                             Blimpie                    85016
#
#    review_count  stars state
# 0            17    2.0    OH
# 1             4    4.5    NC
# 2             7    4.5    ON
# 3             3    3.0    AZ
# 4            10    4.5    AZ

# %%
def unpack(df, column, fillna=None):
    ret = None
    if fillna is None:
        ret = pd.concat([df, pd.DataFrame((d for idx, d in df[column].iteritems()))], axis=1)
        del ret[column]
    else:
        ret = pd.concat([df, pd.DataFrame((d for idx, d in df[column].iteritems())).fillna(fillna)], axis=1)
        del ret[column]
    return ret

unpack_biz_df = unpack(biz_df, 'attributes')
unpack_biz_df = unpack(unpack_biz_df, 'hours')

# %%
unpack_biz_df.head()
# Out:
#                                address             business_id  \
# 0                      691 Richmond Rd  YDf95gJZaq05wvo7hTQbbQ
# 1                       2824 Milton Rd  mLwM-h2YhXl2NCgdS84_Bw
# 2                  337 Danforth Avenue  v2WhjAB3PIBA8J8VxG3wEg
# 3  7702 E Doubletree Ranch Rd, Ste 300  CVtCbSB1zUcUWg-9TNGTuQ
# 4                       4719 N 20Th St  duHFBe87uNSXImQmvBh87Q
#
#                                           categories              city  \
# 0                       [Shopping, Shopping Centers]  Richmond Heights
# 1  [Food, Soul Food, Convenience Stores, Restaura...         Charlotte
# 2                               [Food, Coffee & Tea]           Toronto
# 3               [Professional Services, Matchmakers]        Scottsdale
# 4                          [Sandwiches, Restaurants]           Phoenix
#
#    is_open   latitude   longitude                                name  \
# 0        1  41.541716  -81.493116                Richmond Town Square
# 1        0  35.236870  -80.741976  South Florida Style Chicken & Ribs
# 2        0  43.677126  -79.353285                    The Tea Emporium
# 3        1  33.565082 -111.916400                            TRUmatch
# 4        0  33.505928 -112.038847                             Blimpie
#
#   neighborhood postal_code     ...       Smoking  WheelchairAccessible WiFi  \
# 0                    44143     ...           NaN                  True  NaN
# 1     Eastland       28215     ...           NaN                   NaN  NaN
# 2    Riverdale     M4K 1N7     ...           NaN                  True   no
# 3                    85258     ...           NaN                   NaN  NaN
# 4                    85016     ...           NaN                   NaN   no
#
#         Friday       Monday     Saturday       Sunday     Thursday  \
# 0  10:00-21:00  10:00-21:00  10:00-21:00  11:00-18:00  10:00-21:00
# 1  10:00-22:00  10:00-22:00  10:00-22:00  10:00-22:00  10:00-22:00
# 2  10:00-19:00  10:00-19:00  10:00-18:00  12:00-17:00  10:00-19:00
# 3   9:00-17:00   9:00-17:00          NaN          NaN   9:00-17:00
# 4          NaN          NaN          NaN          NaN          NaN
#
#        Tuesday    Wednesday
# 0  10:00-21:00  10:00-21:00
# 1  10:00-22:00  10:00-22:00
# 2  10:00-19:00  10:00-19:00
# 3   9:00-17:00   9:00-17:00
# 4          NaN          NaN
#
# [5 rows x 59 columns]

# %%
unpack_biz_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156639 entries, 0 to 156638
# Data columns (total 59 columns):
# address                       156639 non-null object
# business_id                   156639 non-null object
# categories                    156639 non-null object
# city                          156639 non-null object
# is_open                       156639 non-null int64
# latitude                      156638 non-null float64
# longitude                     156638 non-null float64
# name                          156639 non-null object
# neighborhood                  156639 non-null object
# postal_code                   156639 non-null object
# review_count                  156639 non-null int64
# stars                         156639 non-null float64
# state                         156639 non-null object
# AcceptsInsurance              8576 non-null object
# AgesAllowed                   395 non-null object
# Alcohol                       44240 non-null object
# Ambience                      42900 non-null object
# BYOB                          905 non-null object
# BYOBCorkage                   1400 non-null object
# BestNights                    6391 non-null object
# BikeParking                   73500 non-null object
# BusinessAcceptsBitcoin        8876 non-null object
# BusinessAcceptsCreditCards    120751 non-null object
# BusinessParking               89439 non-null object
# ByAppointmentOnly             34783 non-null object
# Caters                        34533 non-null object
# CoatCheck                     7976 non-null object
# Corkage                       652 non-null object
# DietaryRestrictions           249 non-null object
# DogsAllowed                   11214 non-null object
# DriveThru                     6040 non-null object
# GoodForDancing                8533 non-null object
# GoodForKids                   58362 non-null object
# GoodForMeal                   42952 non-null object
# HairSpecializesIn             1405 non-null object
# HappyHour                     8416 non-null object
# HasTV                         43728 non-null object
# Music                         8027 non-null object
# NoiseLevel                    40653 non-null object
# Open24Hours                   347 non-null object
# OutdoorSeating                50310 non-null object
# RestaurantsAttire             44813 non-null object
# RestaurantsCounterService     396 non-null object
# RestaurantsDelivery           46803 non-null object
# RestaurantsGoodForGroups      49628 non-null object
# RestaurantsPriceRange2        96355 non-null float64
# RestaurantsReservations       46523 non-null object
# RestaurantsTableService       39961 non-null object
# RestaurantsTakeOut            54648 non-null object
# Smoking                       7673 non-null object
# WheelchairAccessible          44023 non-null object
# WiFi                          43429 non-null object
# Friday                        113360 non-null object
# Monday                        105437 non-null object
# Saturday                      101151 non-null object
# Sunday                        75140 non-null object
# Thursday                      113788 non-null object
# Tuesday                       112215 non-null object
# Wednesday                     113330 non-null object
# dtypes: float64(4), int64(2), object(53)
# memory usage: 70.5+ MB

# %%
for stars in sorted(unpack_biz_df.stars.unique()):
    star_biz_df = unpack_biz_df[unpack_biz_df.stars == stars]
    
    star_biz_df.reset_index(inplace=True, drop=True)
    file = '../clean_data/business/%s_star_businesses.csv' % str(stars).replace('.', '')
    star_biz_df.to_csv(file)
    print(file)
# Out:
# ../clean_data/business/10_star_businesses.csv
# ../clean_data/business/15_star_businesses.csv
# ../clean_data/business/20_star_businesses.csv
# ../clean_data/business/25_star_businesses.csv
# ../clean_data/business/30_star_businesses.csv
# ../clean_data/business/35_star_businesses.csv
# ../clean_data/business/40_star_businesses.csv
# ../clean_data/business/45_star_businesses.csv
# ../clean_data/business/50_star_businesses.csv
