# %% [markdown]
# # Yelp Business Wrangling

# %%
import numpy as np
import pandas as pd
import datetime
import json

DRY_RUN = False

# %%
sample = pd.read_csv('../clean_data/re')

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
# Out:
# <style>.container { width:95% !important; }</style>

# %%
day_labels = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

def time_marker(text=''):
    print('[{}] {}'.format(datetime.datetime.now().time(), text.lower()))

def unpack(df, column, fillna=None):
    ret = None
    if fillna is None:
        ret = pd.concat([df, pd.DataFrame((d for idx, d in df[column].iteritems()))], axis=1)
        del ret[column]
    else:
        ret = pd.concat([df, pd.DataFrame((d for idx, d in df[column].iteritems())).fillna(fillna)], axis=1)
        del ret[column]
    return ret

# %% [markdown]
# # Load Business Data

# %%
time_marker(text='Loading Business Info Data...')

data = pd.DataFrame()
source_data_file = '../source_data/business.json'

biz_list = []
for line in open(source_data_file, 'r'):
    biz_list.append(json.loads(line))

time_marker(text='creating dataframe...')
data = pd.DataFrame(biz_list)

time_marker(text='set index to business_id...')
data.set_index('business_id', inplace=True, drop=True)
    
data.head(3)
# Out:
# [15:05:45.845550] loading business info data...
# [15:05:54.323582] creating dataframe...
# [15:05:55.437396] append business_id prefix column for file sorting...
# [15:05:55.529088] set index to business_id...
#                                     address  \
# business_id
# YDf95gJZaq05wvo7hTQbbQ      691 Richmond Rd
# mLwM-h2YhXl2NCgdS84_Bw       2824 Milton Rd
# v2WhjAB3PIBA8J8VxG3wEg  337 Danforth Avenue
#
#                                                                attributes  \
# business_id
# YDf95gJZaq05wvo7hTQbbQ  {'RestaurantsPriceRange2': 2, 'BusinessParking...
# mLwM-h2YhXl2NCgdS84_Bw  {'GoodForMeal': {'dessert': False, 'latenight'...
# v2WhjAB3PIBA8J8VxG3wEg  {'BusinessParking': {'garage': False, 'street'...
#
#                                                                categories  \
# business_id
# YDf95gJZaq05wvo7hTQbbQ                       [Shopping, Shopping Centers]
# mLwM-h2YhXl2NCgdS84_Bw  [Food, Soul Food, Convenience Stores, Restaura...
# v2WhjAB3PIBA8J8VxG3wEg                               [Food, Coffee & Tea]
#
#                                     city  \
# business_id
# YDf95gJZaq05wvo7hTQbbQ  Richmond Heights
# mLwM-h2YhXl2NCgdS84_Bw         Charlotte
# v2WhjAB3PIBA8J8VxG3wEg           Toronto
#
#                                                                     hours  \
# business_id
# YDf95gJZaq05wvo7hTQbbQ  {'Monday': '10:00-21:00', 'Tuesday': '10:00-21...
# mLwM-h2YhXl2NCgdS84_Bw  {'Monday': '10:00-22:00', 'Tuesday': '10:00-22...
# v2WhjAB3PIBA8J8VxG3wEg  {'Monday': '10:00-19:00', 'Tuesday': '10:00-19...
#
#                         is_open   latitude  longitude  \
# business_id
# YDf95gJZaq05wvo7hTQbbQ        1  41.541716 -81.493116
# mLwM-h2YhXl2NCgdS84_Bw        0  35.236870 -80.741976
# v2WhjAB3PIBA8J8VxG3wEg        0  43.677126 -79.353285
#
#                                                       name neighborhood  \
# business_id
# YDf95gJZaq05wvo7hTQbbQ                Richmond Town Square
# mLwM-h2YhXl2NCgdS84_Bw  South Florida Style Chicken & Ribs     Eastland
# v2WhjAB3PIBA8J8VxG3wEg                    The Tea Emporium    Riverdale
#
#                        postal_code  review_count  stars state bid_prefix
# business_id
# YDf95gJZaq05wvo7hTQbbQ       44143            17    2.0    OH          Y
# mLwM-h2YhXl2NCgdS84_Bw       28215             4    4.5    NC          m
# v2WhjAB3PIBA8J8VxG3wEg     M4K 1N7             7    4.5    ON          v

# %% [markdown]
# # Separate `hours` column into daily open and close columns

# %%
time_marker(text='collecting business Hours...')
hours = data[['hours']].copy()

time_marker('splitting hours into individual columns...')
hours = pd.concat([hours.drop(['hours'], axis=1), hours['hours'].apply(pd.Series)], axis=1)

time_marker(text='Split hours into open and close...')
# split daily hours columns into '{DAY}_open' and '{DAY}_close'
for col in hours.columns:

    # split hours column of [11:00-19:00] into '{original_name}_open' and '{original_name}_close' columns
    hours['{}_open'.format(col.lower())]  = pd.to_datetime(hours[col].str.split('-', 1).str[0], format='%H:%M').dt.time
    hours['{}_close'.format(col.lower())] = pd.to_datetime(hours[col].str.split('-', 1).str[1], format='%H:%M').dt.time
    
    # drop original day columns
    hours.drop(col, axis=1, inplace=True)

time_marker('sorting day columns order...')
cols = [['{}_open'.format(x.lower()), '{}_close'.format(x.lower())] for x in day_labels]
ordered_cols = list()
for day in cols:
    for time in day:
        ordered_cols.append(time)
        
hours = hours[ordered_cols].copy()

# merge back to original data frame
time_marker(text='merge open and close hours to business data...')
data = data.merge(hours, left_index=True, right_index=True)

data.drop(['hours'], axis=1, inplace=True)

data.head(10)
# Out:
# [15:08:11.888856] collecting business hours...
# [15:08:11.904895] splitting hours into individual columns...
# [15:09:30.504588] split hours into open and close...
# [15:09:58.999652] sorting day columns order...
# [15:09:59.102873] merge open and close hours to business data...
#                                                     address  \
# business_id
# YDf95gJZaq05wvo7hTQbbQ                      691 Richmond Rd
# mLwM-h2YhXl2NCgdS84_Bw                       2824 Milton Rd
# v2WhjAB3PIBA8J8VxG3wEg                  337 Danforth Avenue
# CVtCbSB1zUcUWg-9TNGTuQ  7702 E Doubletree Ranch Rd, Ste 300
# duHFBe87uNSXImQmvBh87Q                       4719 N 20Th St
# uUEMrhJiL1a1pCA_I1SU7Q                  2017 E Camelback Rd
# 2eJEUJIP54tex7T9YOcLSw              4425 N 24th St, Ste 125
# fEylCY3UEH8YJ0Xa7lu6lA                       5770 Butler St
# kFtuYklkAIlmYw8RZAieGw                   3220 Washington Rd
# NqiQdFa93wzUJGo29NbTPQ            1425 S Higley Rd, Ste 103
#
#                                                                attributes  \
# business_id
# YDf95gJZaq05wvo7hTQbbQ  {'RestaurantsPriceRange2': 2, 'BusinessParking...
# mLwM-h2YhXl2NCgdS84_Bw  {'GoodForMeal': {'dessert': False, 'latenight'...
# v2WhjAB3PIBA8J8VxG3wEg  {'BusinessParking': {'garage': False, 'street'...
# CVtCbSB1zUcUWg-9TNGTuQ                                                 {}
# duHFBe87uNSXImQmvBh87Q  {'RestaurantsTableService': False, 'GoodForMea...
# uUEMrhJiL1a1pCA_I1SU7Q  {'BusinessAcceptsCreditCards': True, 'Restaura...
# 2eJEUJIP54tex7T9YOcLSw  {'AcceptsInsurance': True, 'ByAppointmentOnly'...
# fEylCY3UEH8YJ0Xa7lu6lA               {'BusinessAcceptsCreditCards': True}
# kFtuYklkAIlmYw8RZAieGw  {'DogsAllowed': True, 'BusinessParking': {'gar...
# NqiQdFa93wzUJGo29NbTPQ  {'AcceptsInsurance': True, 'ByAppointmentOnly'...
#
#                                                                categories  \
# business_id
# YDf95gJZaq05wvo7hTQbbQ                       [Shopping, Shopping Centers]
# mLwM-h2YhXl2NCgdS84_Bw  [Food, Soul Food, Convenience Stores, Restaura...
# v2WhjAB3PIBA8J8VxG3wEg                               [Food, Coffee & Tea]
# CVtCbSB1zUcUWg-9TNGTuQ               [Professional Services, Matchmakers]
# duHFBe87uNSXImQmvBh87Q                          [Sandwiches, Restaurants]
# uUEMrhJiL1a1pCA_I1SU7Q                          [Shopping, Tobacco Shops]
# 2eJEUJIP54tex7T9YOcLSw                  [Chiropractors, Health & Medical]
# fEylCY3UEH8YJ0Xa7lu6lA  [Automotive, Oil Change Stations, Car Wash, Au...
# kFtuYklkAIlmYw8RZAieGw  [Jewelry Repair, Gold Buyers, Local Services, ...
# NqiQdFa93wzUJGo29NbTPQ                   [Health & Medical, Optometrists]
#
#                                     city  is_open   latitude   longitude  \
# business_id
# YDf95gJZaq05wvo7hTQbbQ  Richmond Heights        1  41.541716  -81.493116
# mLwM-h2YhXl2NCgdS84_Bw         Charlotte        0  35.236870  -80.741976
# v2WhjAB3PIBA8J8VxG3wEg           Toronto        0  43.677126  -79.353285
# CVtCbSB1zUcUWg-9TNGTuQ        Scottsdale        1  33.565082 -111.916400
# duHFBe87uNSXImQmvBh87Q           Phoenix        0  33.505928 -112.038847
# uUEMrhJiL1a1pCA_I1SU7Q           Phoenix        0  33.508068 -112.037552
# 2eJEUJIP54tex7T9YOcLSw           Phoenix        1  33.502848 -112.012696
# fEylCY3UEH8YJ0Xa7lu6lA        Pittsburgh        1  40.485939  -79.943727
# kFtuYklkAIlmYw8RZAieGw          McMurray        1  40.290498  -80.110021
# NqiQdFa93wzUJGo29NbTPQ           Gilbert        1  33.324539 -111.720449
#
#                                                       name   neighborhood  \
# business_id
# YDf95gJZaq05wvo7hTQbbQ                Richmond Town Square
# mLwM-h2YhXl2NCgdS84_Bw  South Florida Style Chicken & Ribs       Eastland
# v2WhjAB3PIBA8J8VxG3wEg                    The Tea Emporium      Riverdale
# CVtCbSB1zUcUWg-9TNGTuQ                            TRUmatch
# duHFBe87uNSXImQmvBh87Q                             Blimpie
# uUEMrhJiL1a1pCA_I1SU7Q                     Baxter's Cigars
# 2eJEUJIP54tex7T9YOcLSw            Back-Health Chiropractic
# fEylCY3UEH8YJ0Xa7lu6lA                       Auto Bathouse  Lawrenceville
# kFtuYklkAIlmYw8RZAieGw                 JAB Jewelry Designs
# NqiQdFa93wzUJGo29NbTPQ          Neighborhood Vision Center
#
#                        postal_code     ...       wednesday_open  \
# business_id                            ...
# YDf95gJZaq05wvo7hTQbbQ       44143     ...             10:00:00
# mLwM-h2YhXl2NCgdS84_Bw       28215     ...             10:00:00
# v2WhjAB3PIBA8J8VxG3wEg     M4K 1N7     ...             10:00:00
# CVtCbSB1zUcUWg-9TNGTuQ       85258     ...             09:00:00
# duHFBe87uNSXImQmvBh87Q       85016     ...                  NaN
# uUEMrhJiL1a1pCA_I1SU7Q       85016     ...             10:00:00
# 2eJEUJIP54tex7T9YOcLSw       85016     ...             14:30:00
# fEylCY3UEH8YJ0Xa7lu6lA       15201     ...             08:00:00
# kFtuYklkAIlmYw8RZAieGw       15317     ...             10:00:00
# NqiQdFa93wzUJGo29NbTPQ       85296     ...             07:30:00
#
#                         wednesday_close thursday_open thursday_close  \
# business_id
# YDf95gJZaq05wvo7hTQbbQ         21:00:00      10:00:00       21:00:00
# mLwM-h2YhXl2NCgdS84_Bw         22:00:00      10:00:00       22:00:00
# v2WhjAB3PIBA8J8VxG3wEg         19:00:00      10:00:00       19:00:00
# CVtCbSB1zUcUWg-9TNGTuQ         17:00:00      09:00:00       17:00:00
# duHFBe87uNSXImQmvBh87Q              NaN           NaN            NaN
# uUEMrhJiL1a1pCA_I1SU7Q         20:00:00      10:00:00       20:00:00
# 2eJEUJIP54tex7T9YOcLSw         17:00:00      14:00:00       19:00:00
# fEylCY3UEH8YJ0Xa7lu6lA         17:00:00      08:00:00       17:00:00
# kFtuYklkAIlmYw8RZAieGw         20:00:00      10:00:00       20:00:00
# NqiQdFa93wzUJGo29NbTPQ         17:00:00      07:30:00       17:00:00
#
#                        friday_open friday_close saturday_open saturday_close  \
# business_id
# YDf95gJZaq05wvo7hTQbbQ    10:00:00     21:00:00      10:00:00       21:00:00
# mLwM-h2YhXl2NCgdS84_Bw    10:00:00     22:00:00      10:00:00       22:00:00
# v2WhjAB3PIBA8J8VxG3wEg    10:00:00     19:00:00      10:00:00       18:00:00
# CVtCbSB1zUcUWg-9TNGTuQ    09:00:00     17:00:00           NaN            NaN
# duHFBe87uNSXImQmvBh87Q         NaN          NaN           NaN            NaN
# uUEMrhJiL1a1pCA_I1SU7Q    10:00:00     21:00:00      10:00:00       21:00:00
# 2eJEUJIP54tex7T9YOcLSw    09:00:00     12:00:00           NaN            NaN
# fEylCY3UEH8YJ0Xa7lu6lA    08:00:00     17:00:00      08:00:00       17:00:00
# kFtuYklkAIlmYw8RZAieGw    10:00:00     18:00:00      10:00:00       16:00:00
# NqiQdFa93wzUJGo29NbTPQ    07:30:00     11:00:00           NaN            NaN
#
#                        sunday_open sunday_close
# business_id
# YDf95gJZaq05wvo7hTQbbQ    11:00:00     18:00:00
# mLwM-h2YhXl2NCgdS84_Bw    10:00:00     22:00:00
# v2WhjAB3PIBA8J8VxG3wEg    12:00:00     17:00:00
# CVtCbSB1zUcUWg-9TNGTuQ         NaN          NaN
# duHFBe87uNSXImQmvBh87Q         NaN          NaN
# uUEMrhJiL1a1pCA_I1SU7Q    10:00:00     19:00:00
# 2eJEUJIP54tex7T9YOcLSw         NaN          NaN
# fEylCY3UEH8YJ0Xa7lu6lA    08:00:00     16:30:00
# kFtuYklkAIlmYw8RZAieGw         NaN          NaN
# NqiQdFa93wzUJGo29NbTPQ         NaN          NaN
#
# [10 rows x 28 columns]

# %% [markdown]
# # Separate `attributes` column into columns

# %%
time_marker('splitting out attributes columns...')
attributes_df = data['attributes'].apply(pd.Series)
attributes_df.columns = [str(x).lower() for x in attributes_df.columns]
time_marker('done')
# Out:
# [15:30:19.854574] splitting out attributes columns...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-68-19aa6e432616> in <module>()
#       1 time_marker('splitting out attributes columns...')
# ----> 2 attributes_df = data['attributes'].apply(pd.Series)
#       3 attributes_df.columns = [str(x).lower() for x in attributes_df.columns]
#       4 time_marker('done')
#
# ~/anaconda/lib/python3.6/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    2357         if len(mapped) and isinstance(mapped[0], Series):
#    2358             from pandas.core.frame import DataFrame
# -> 2359             return DataFrame(mapped.tolist(), index=self.index)
#    2360         else:
#    2361             return self._constructor(mapped,
#
# ~/anaconda/lib/python3.6/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     312                     if is_named_tuple(data[0]) and columns is None:
#     313                         columns = data[0]._fields
# --> 314                     arrays, columns = _to_arrays(data, columns, dtype=dtype)
#     315                     columns = _ensure_index(columns)
#     316
#
# ~/anaconda/lib/python3.6/site-packages/pandas/core/frame.py in _to_arrays(data, columns, coerce_float, dtype)
#    5622         return _list_of_series_to_arrays(data, columns,
#    5623                                          coerce_float=coerce_float,
# -> 5624                                          dtype=dtype)
#    5625     elif isinstance(data[0], Categorical):
#    5626         if columns is None:
#
# ~/anaconda/lib/python3.6/site-packages/pandas/core/frame.py in _list_of_series_to_arrays(data, columns, coerce_float, dtype)
#    5716             indexer = indexer_cache[id(index)]
#    5717         else:
# -> 5718             indexer = indexer_cache[id(index)] = index.get_indexer(columns)
#    5719
#    5720         values = _values_from_object(s)
#
# ~/anaconda/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_indexer(self, target, method, limit, tolerance)
#    2580                                     tolerance=tolerance)
#    2581
# -> 2582         if not self.is_unique:
#    2583             raise InvalidIndexError('Reindexing only valid with uniquely'
#    2584                                     ' valued Index objects')
#
# pandas/_libs/src/properties.pyx in pandas._libs.lib.cache_readonly.__get__ (pandas/_libs/lib.c:44594)()
#
# ~/anaconda/lib/python3.6/site-packages/pandas/core/indexes/base.py in is_unique(self)
#    1259     def is_unique(self):
#    1260         """ return if the index has unique values """
# -> 1261         return self._engine.is_unique
#    1262
#    1263     @property
#
# KeyboardInterrupt:

# %%
time_marker('expanding attributes...')
expandable_cols = ['businessparking','goodformeal','ambience','hairspecializesin','music','bestnights','dietaryrestrictions']

for excol in [col for col in attributes_df.columns if col != 0]:
    time_marker('\texpanding "{}"...'.format(excol))
    df = attributes_df[excol].apply(pd.Series)
    df.columns = ['{}_{}'.format(excol, str(x).lower()) for x in df.columns]
    
    # append to attributes_df
    attributes_df = attributes_df.merge(df, left_index=True, right_index=True)
    
    # drop original column
    attributes_df.drop([excol], axis=1, inplace=True)

# if attribute column ends in '_0', trim it
time_marker('trimming odd columns...')
col_names = list()
for col in attributes_df.columns:
    if col.endswith('_0'):
        col_names.append(col[:-2])
    else:
        col_names.append(col)
# correct collumn names
attributes_df.columns = col_names

time_marker('dropping columns of all nan...')
attributes_df=attributes_df.dropna(axis=1,how='all')
# Out:
# [15:25:49.474095] expanding acceptsinsurance...
# [15:25:49.487835] expanding alcohol...
# [15:25:49.500423] expanding ambience...
# [15:25:49.526968] expanding bikeparking...
# [15:25:49.538870] expanding businessacceptsbitcoin...
# [15:25:49.549766] expanding businessacceptscreditcards...
# [15:25:49.562097] expanding businessparking...
# [15:25:49.584688] expanding byappointmentonly...
# [15:25:49.595647] expanding caters...
# [15:25:49.609705] expanding coatcheck...
# [15:25:49.620464] expanding dogsallowed...
# [15:25:49.632662] expanding drivethru...
# [15:25:49.644475] expanding goodfordancing...
# [15:25:49.656696] expanding goodforkids...
# [15:25:49.667902] expanding goodformeal...
# /Users/samgutentag/anaconda/lib/python3.6/site-packages/pandas/core/indexes/api.py:77: RuntimeWarning: '>' not supported between instances of 'str' and 'int', sort order is undefined for incomparable objects
#   result = result.union(other)
# /Users/samgutentag/anaconda/lib/python3.6/site-packages/pandas/core/indexes/api.py:43: RuntimeWarning: '>' not supported between instances of 'str' and 'int', sort order is undefined for incomparable objects
#   union = _union_indexes(indexes)
# /Users/samgutentag/anaconda/lib/python3.6/site-packages/pandas/core/indexes/api.py:43: RuntimeWarning: '>' not supported between instances of 'int' and 'str', sort order is undefined for incomparable objects
#   union = _union_indexes(indexes)
# /Users/samgutentag/anaconda/lib/python3.6/site-packages/pandas/core/indexes/api.py:77: RuntimeWarning: '>' not supported between instances of 'int' and 'str', sort order is undefined for incomparable objects
#   result = result.union(other)
# [15:25:49.694075] expanding hairspecializesin...
# [15:25:49.719891] expanding happyhour...
# [15:25:49.737525] expanding hastv...
# [15:25:49.754010] expanding music...
# [15:25:49.782390] expanding noiselevel...
# [15:25:49.795498] expanding outdoorseating...
# [15:25:49.808579] expanding restaurantsattire...
# [15:25:49.823871] expanding restaurantsdelivery...
# [15:25:49.837789] expanding restaurantsgoodforgroups...
# [15:25:49.850584] expanding restaurantspricerange2...
# [15:25:49.863195] expanding restaurantsreservations...
# [15:25:49.876486] expanding restaurantstableservice...
# [15:25:49.888548] expanding restaurantstakeout...
# [15:25:49.900703] expanding wheelchairaccessible...
# [15:25:49.913229] expanding wifi...
# [15:25:49.927153] trimming odd columns...
# [15:25:49.927843] dropping columns of all nan...

# %% [markdown]
# ### Merge back to biz_df

# %%
time_marker('merging attributes to main business dataframe...')
data = data.merge(attributes_df, left_index=True, right_index=True)
data.drop(['attributes'], axis=1, inplace=True)
time_marker('done')
data.head(3)

# %% [markdown]
# # One Hot Encode `categories` with sklearn
# <p>Save to separate file</p>

# %%
from sklearn.preprocessing import MultiLabelBinarizer
mlb = MultiLabelBinarizer()

# %%
data = data[['business_id', 'categories']].copy()
data.set_index('business_id', inplace=True)
data.head(3)

# %%
time_marker('one hot encoding of categories started...')
data = data.join(pd.DataFrame(mlb.fit_transform(data.pop('categories')),
                          columns=mlb.classes_,
                          index=data.index))
time_marker('complete!')

# %% [markdown]
# # Write to Files

# %%
time_marker('append business_id prefix column for file sorting...')
data['bid_prefix'] = data.business_id.apply(lambda x: x[:1])

# %%
time_marker(text='Writing to files...')
file_count = len(reviews.bid_prefix.unique())

for i, prefix in enumerate(sorted(data.bid_prefix.unique())):
    df = reviews[reviews.bid_prefix == prefix].iloc[:,:-1].copy()
    df.reset_index(inplace=True, drop=True)
    file_name = '../clean_data/business/{}_{}_business_clean.csv'.format(str(i).zfill(2), prefix)
    time_marker(text='Writing {:d} records to file {}'.format(df.shape[0], file_name))
    if DRY_RUN:
        pass
    else:
        df.to_csv(file_name, encoding='utf-8')
time_marker(text='Done!')
